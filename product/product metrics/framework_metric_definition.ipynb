# %% [markdown]
# <a href="https://colab.research.google.com/github/mikeogunmakin/research/blob/main/product/product%20metrics/framework_metric_definition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Metric Definition Framework**

# %% [markdown]
# ### 1. Metric Definition

# %% [markdown]
# - Name:
# - Description:
# - Formula:
# - Grain: (e.g., user, session, campaign)
# - Time Window: (e.g., daily, weekly, rolling 7-day)
# - Data Sources:
# - Transformation Logic: (filters, joins, attribution rules)

# %% [markdown]
# ### 2. Business Context

# %% [markdown]
# - Purpose: (why this metric exists)
# - Decision Use: (what decisions it informs)
# - Link to Goals: (how it ties to company/KPI objectives)

# %% [markdown]
# ### 3. Classification

# %% [markdown]
# - Metric Type: (North Star / Driver / Guardrail / Diagnostic)
# - Related Metrics: (what it influences or depends on)

# %% [markdown]
# ### 4. Quality & Limitations

# %% [markdown]
# - Validation Checks: (sanity checks, expected behaviour)
# - Reconciliation: (does it match finance/other sources?)
# - Known Limitations: (biases, tracking gaps, lag effects)

# %% [markdown]
# ### 5. Ownership & Governance

# %% [markdown]
# - Owner: (team/person responsible)
# - Update Frequency:
# - Version / Last Updated:

# %% [markdown]
# ### 6. Usage Guidelines

# %% [markdown]
# - When to Use:
# - Experiment Suitability: (primary/secondary, not suitable, etc.)
# - Aggregation Rules: (can it be summed? safe breakdowns?)
# - Common Pitfalls:
