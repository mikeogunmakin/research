# %% [markdown]
# <a href="https://colab.research.google.com/github/mikeogunmakin/research/blob/main/bsts%20modelling%20/%20theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# what is bayesian structural time series (BSTS)?
#
# what is the implication of using BSTS
